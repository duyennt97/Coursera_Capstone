# %% [markdown]
# # CAPSTONE PROJECT

# %% [markdown]
# ## Introduction

# %% [markdown]
# 1. Business Problem

# %% [markdown]
# - STARHOTEL is a company who already have hotels in Spain and now wants to open a new hotel this year in Barcelona, the city of the famous football team FC Barcelone. It is also known as the 2nd largest city in Spain, top 10 attactive destination and the city appeals lots of tourists every year.
# - Opening a new hotel in Barcelona is considered a good decision. Location is one of most important feature that the company concerns. However, STARHOTEL hasn't got much information about the city yet. Barcelona has 10 different districts and it will be very risky if no research done before choosing a specific district. Therefore, this project comes to identify the best district to open the new hotel in Barcelona

# %% [markdown]
# ![du-lich-barcelone.png](attachment:du-lich-barcelone.png)

# %% [markdown]
# Now we will try to find the answers to the folowing questions:
# - Which info that STARHOTEL should use to choose the district of their new hotel? Which specific district is that?
# - What is the district in the 2nd place that can replace the 1st one we find out (if needed)
# - The related hotels in the same area those could affect and be the competitors of our new hotel
